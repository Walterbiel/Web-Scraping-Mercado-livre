# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import time

# Configuração do Selenium
options = Options()
options.add_argument("--headless")  # Executa em segundo plano
options.add_argument("--disable-gpu")
options.add_argument("--window-size=1920x1080")

driver = webdriver.Chrome()

# Lista de categorias para buscar (URLs das categorias do Mercado Livre)
categorias = [
    "https://lista.mercadolivre.com.br/figure-action#D[A:figure%20action,L:undefined]"
]

output = {}

for categoria in categorias:
        driver.get(categoria)
        time.sleep(3)  # Espera carregar a página

# %%
for categoria in categorias:
    driver.get(categoria)
    time.sleep(3)  # Espera carregar a página
    
categoria_nome = driver.find_element(By.TAG_NAME, "h1").text

produtos = driver.find_elements(By.CLASS_NAME,"ui-search-layout__item")

output = {}

produtos = driver.find_elements(By.CLASS_NAME, "ui-search-layout__item")
categoria_nome = driver.find_element(By.TAG_NAME, "h1").text

output[categoria_nome] = []  # Inicializa uma lista para armazenar os produtos da categoria

for produto in produtos:
    lista = []
    try:
        nome = produto.find_element(By.CLASS_NAME, "poly-component__title").text
    except:
        nome = "nd"
    try:
        qtd_avaliacoes = produto.find_element(By.CLASS_NAME, "poly-reviews__total").text
    except:
        qtd_avaliacoes = "nd"
    try:
        nota = produto.find_element(By.CLASS_NAME, "poly-reviews__rating").text
    except:
        nota = "nd"
    try:
        preco = produto.find_element(By.CLASS_NAME, "andes-money-amount__fraction").text
    except:
        preco = "nd"
    try:
        link = produto.find_element(By.TAG_NAME, "a").get_attribute("href")
    except:
        link = "nd"

    lista.append(nome)
    lista.append(qtd_avaliacoes)
    lista.append(nota)
    lista.append(preco)
    lista.append(link)
    
    output[categoria_nome].append(lista)

display(output)
# Out:
# {'Figure action': [['Boneco Dummy 13 Multi Articulado Varias Posições Lucky 13',
#    '(7)',
#    '4.3',
#    '60',
#    'https://click1.mercadolivre.com.br/mclics/clicks/external/MLB/count?a=DxK9bI%2BTIIvkrxNso9P41F9zVhY5EdEvBJpOxO4MS65SMRI4hNanypQ9Rar5TeXjDoXg9rKCGZygdNk7zHP4YIpi6qWBAbtqsWjjggJrf1S5tf7ckulxJP46rj3rT40691zB2ziUtdmuwuqy%2FOfMXUUIutR5Owme3dqjaPhQmBh3aDJmRD%2FHlh3eTEGGVd1e6K4gZBnd%2FBJWKl%2FCD8uOu%2BKd3XApTa82l1v4lL%2B34I0fIHlR60DUPqPvnorh0zzwHROtezUo27HH30n7%2F82I9WMitJz5QJOLYJFZBnuLs1crXPF0SeiDTlFDoAkwvH2AFC51%2Fg%2BLPJ%2Ba9OS3eQerdEEpuMTegzaRkJ73cbqVJeGMgsWWOklVljaAPZD3eWKYs9tsB0MsTeH1cWOYxbXIPD2hV2w2kyn%2BaE0QD5OZc6VQ10iz%2FSwx9RnFm1TQwRX%2FbWJEI3KHuOZBXrqPtdDZrCxOGokBC%2Bgdh8p1gHLgiE8bChBzv%2BS6lmZ3KGArgpTTcyyijK6bPC3S6gUZKliUUGk3ErkoUPJAvUlLsZ1gm8719hk7pyWTv1fSkdejlkEm3aqNGuAzZ0mT82y%2B4aAiqEGl56EQCNpnE7SINjdS4tl0P%2BiCN%2BesNJLYkw65xNHdUysfYkv0nP%2BSSTSehIIhrRjKGfCOs6b6aZV8XogYudz2kSykJHKt0ZgBh6vew9ZjE284wXRyC4yOaW%2Bk3k2eIfSmAYm19ARS9P19rzm15TzAYiw2kwHdsZXdgGJ6R1Ul11PK01v4n3JYs18c6I%2BHDMocpnXzCyMPodcXt%2F8i4lBnTBkcfE1y%2BqqRV1WhjZRiRpsbbs2tnsilsMHM2lsLu28Yy0EQ428%2BhGQWtKd9pHQ%3D&rb=x#polycard_client=search-nordic&tracking_id=d60c0833-5510-41b0-8fb7-adc3805169c5'],
#   ['Boneco Articulado Lucky Robô 3d Action Figure Dummy Enfeite',
#    '(134)',
#    '4.2',
#    '44',
#    'https://click1.mercadolivre.com.br/mclics/clicks/external/MLB/count?a=vanZQZxKZzqrv3tUry5VrNmussQrYaLmSD7xmH3K8G3GimEpGUWJ2aTIuriW5vVE%2BFYSDlr4XrNApzhKIXbh2mUzQF%2Fgb67Pb%2BmC1E5wm3vwlmk4HptnPeGjNK3Fg0MrPtAzgsAsl3pU5Itj0I73MIHORKFeYrmDu0QbDI8knSrL9zjsa1%2B7PngsW0onh7OFtSlfGhPhFamN8ob5kR7q%2BFFPVPnqQu%2BjGUu7kNK%2Ba8hiH8qIzx2XKylBXKpdakJyNqWIM2wYmDy0YZeOKWGxOYfFmpeM65RsFoGIRoLHS%2BSRB1dzjiC%2ByZIJoKkj1G4AM66yiAHR%2F%2Bwv3jXiUYz%2Fo1c0thPDuNKceJsM2T4%2B%2Fp7i0lSi6zW35rDn5pEjvM%2BOAT0uzO8xPOD20hNhnqi27WGi3hO65fIxqkcWP6pG5Ba30tU0%2BvLiZlY4OztWCStaG2nppFCXDWiQXM1FKPS8pHdaHAe4jiK5Qe%2FbPlEDu9FAumHAayHkN%2BN3mPW%2BvPw1%2BPJ7EcteOdXz6MveQ2kLEvv0hwNfBsheRR9PjOHPm%2FpRK3pc%2BY7t8Kmn%2BiHOP3fzxqM11n0pd1w6q80Od2hYJcjNz1O5jNJr03amiNZUvPFkGpgWflLlffzl024%2FJvOoAyXrdR032ME0opzWUEPFRurllNbjVQx1g9imaXblpOEBOxTVfNFNcmP81ZqQHfN5niHGs12%2FNMYpHNbfn1PgqYaYSs9h%2FCbg2XjoPsUjXVMXnKv%2BFG6guCJmHZYcfW5BmKRSe4RflmdNqoPifQBOaKz84tMyIhRQfTo%2FMxAzP5pd5qohbLx7BlbYJsNrpn32dbujwzAc0tHP7Kk1g%2FH8XioaQ1HyLZGzSG9mWtV%2FiIA7&rb=x#polycard_client=search-nordic&tracking_id=d60c0833-5510-41b0-8fb7-adc3805169c5'],
#   ['Homem Aranha Action Figure Miles Morales Aranha Verso',
#    '(179)',
#    '4.3',
#    '149',
#    'https://www.mercadolivre.com.br/homem-aranha-action-figure-miles-morales-aranha-verso/p/MLB26721764#polycard_client=search-nordic&searchVariation=MLB26721764&wid=MLB3802066809&position=4&search_layout=grid&type=product&tracking_id=d60c0833-5510-41b0-8fb7-adc3805169c5&sid=search'],
#   ['Optimus Prime Transformers Action Figure Boneco Vira Robo',
#    '(164)',
#    '4.2',
#    '156',
#    'https://www.mercadolivre.com.br/optimus-prime-transformers-action-figure-boneco-vira-robo/p/MLB32164102#polycard_client=search-nordic&searchVariation=MLB32164102&wid=MLB4581096242&position=5&search_layout=grid&type=product&tracking_id=d60c0833-5510-41b0-8fb7-adc3805169c5&sid=search'],
#   ['Luffy Articulado Action Figure One Piece Boneco Luffy',
#    '(103)',
#    '3.9',
#    '144',
#    'https://www.mercadolivre.com.br/luffy-articulado-action-figure-one-piece-boneco-luffy/p/MLB30200681#polycard_client=search-nordic&searchVariation=MLB30200681&wid=MLB4943623754&position=3&search_layout=grid&type=product&tracking_id=d60c0833-5510-41b0-8fb7-adc3805169c5&sid=search'],
#   ['Boneco Baby Yoda Bebê Star Wars Mandalorian Série Tv Filme',
#    '(403)',
#    '4.8',
#    '167',
#    'https://www.mercadolivre.com.br/boneco-baby-yoda-beb-star-wars-mandalorian-serie-tv-filme/p/MLB20789395#polycard_client=search-nordic&searchVariation=MLB20789395&wid=MLB5070807848&position=8&search_layout=grid&type=product&tracking_id=d60c0833-5510-41b0-8fb7-adc3805169c5&sid=search'],
#   ['Kit 10 Bonecos Action Figure Harry Potter Hermione Rony',
#    '(121)',
#    '4.8',
#    '128',
#    'https://www.mercadolivre.com.br/kit-10-bonecos-action-figure-harry-potter-hermione-rony/p/MLB27911069#polycard_client=search-nordic&searchVariation=MLB27911069&wid=MLB3677554567&position=15&search_layout=grid&type=product&tracking_id=d60c0833-5510-41b0-8fb7-adc3805169c5&sid=search'],
#   ['Hasbro Vingadores Marvel Boneco Duende Verde F4983 Titan Hero Series 30cm',
#    '(246)',
#    '4.9',
#    '44',
#    'https://www.mercadolivre.com.br/hasbro-vingadores-marvel-boneco-duende-verde-f4983-titan-hero-series-30cm/p/MLB23202177#polycard_client=search-nordic&searchVariation=MLB23202177&wid=MLB3575703375&position=22&search_layout=grid&type=product&tracking_id=d60c0833-5510-41b0-8fb7-adc3805169c5&sid=search'],
#   ['Action Figure Optimus Prime Boneco Transformers Vira Robo',
#    '(102)',
#    '4.3',
#    '111',
#    'https://www.mercadolivre.com.br/action-figure-optimus-prime-boneco-transformers-vira-robo/p/MLB36752453#polycard_client=search-nordic&searchVariation=MLB36752453&wid=MLB4679333250&position=25&search_layout=grid&type=product&tracking_id=d60c0833-5510-41b0-8fb7-adc3805169c5&sid=search'],
#   ['Link Zelda Tears Of The Kingdom Figurizma Sega Action Figure',
#    'nd',
#    'nd',
#    '550',
#    'https://produto.mercadolivre.com.br/MLB-5264391246-link-zelda-tears-of-the-kingdom-figurizma-sega-action-figure-_JM#polycard_client=search-nordic&position=29&search_layout=grid&type=item&tracking_id=d60c0833-5510-41b0-8fb7-adc3805169c5'],
#   ['Boneco Dummy 13 Multi Articulado Varias Posições Lucky 13',
#    '(7)',
#    '4.3',
#    '60',
#    'https://produto.mercadolivre.com.br/MLB-3912008217-boneco-dummy-13-multi-articulado-varias-posicoes-lucky-13-_JM?searchVariation=182268413042#polycard_client=search-nordic&searchVariation=182268413042&position=30&search_layout=grid&type=item&tracking_id=d60c0833-5510-41b0-8fb7-adc3805169c5'],
#   ['Anime Naruto Figure Change Face Figures Naruto Action',
#    '(8)',
#    '3.6',
#    '71',
#    'https://www.mercadolivre.com.br/anime-naruto-figure-change-face-figures-naruto-action/p/MLB2000297782#polycard_client=search-nordic&searchVariation=MLB2000297782&wid=MLB3802944087&position=28&search_layout=grid&type=product&tracking_id=d60c0833-5510-41b0-8fb7-adc3805169c5&sid=search'],
#   ['Bumblebee Transformers Action Figure Boneco Vira Robo',
#    '(58)',
#    '4.9',
#    '190',
#    'https://www.mercadolivre.com.br/bumblebee-transformers-action-figure-boneco-vira-robo/p/MLB32114105#polycard_client=search-nordic&searchVariation=MLB32114105&wid=MLB3613362171&position=27&search_layout=grid&type=product&tracking_id=d60c0833-5510-41b0-8fb7-adc3805169c5&sid=search'],
#   ['Boneco Marvel Homem Aranha Titan Hero Series 30 Cm',
#    '(1214)',
#    '4.8',
#    '109',
#    'https://www.mercadolivre.com.br/boneco-marvel-homem-aranha-titan-hero-series-30-cm/p/MLB7879678#polycard_client=search-nordic&searchVariation=MLB7879678&wid=MLB3932975020&position=16&search_layout=grid&type=product&tracking_id=d60c0833-5510-41b0-8fb7-adc3805169c5&sid=search'],
#   ['Boneco Hulk Marvel Vingadores Huck',
#    '(427)',
#    '4.8',
#    '71',
#    'https://www.mercadolivre.com.br/boneco-hulk-marvel-vingadores-huck/p/MLB19545371#polycard_client=search-nordic&searchVariation=MLB19545371&wid=MLB5213078120&position=21&search_layout=grid&type=product&tracking_id=d60c0833-5510-41b0-8fb7-adc3805169c5&sid=search'],
#   ['Kit One Piece Luffy E Zoro Bonecos Pvc Action Figure Coleção',
#    '(7)',
#    '5.0',
#    '100',
#    'https://www.mercadolivre.com.br/kit-one-piece-luffy-e-zoro-bonecos-pvc-action-figure-coleco/p/MLB41209624#polycard_client=search-nordic&searchVariation=MLB41209624&wid=MLB3912734051&position=23&search_layout=grid&type=product&tracking_id=d60c0833-5510-41b0-8fb7-adc3805169c5&sid=search'],
#   ['One Piece Brinquedo Monkey D Luffy Zoro Boneco Estátua 18cm',
#    '(42)',
#    '4.8',
#    '60',
#    'https://www.mercadolivre.com.br/one-piece-brinquedo-monkey-d-luffy-zoro-boneco-estatua-18cm/p/MLB29773811#polycard_client=search-nordic&searchVariation=MLB29773811&wid=MLB5179025954&position=17&search_layout=grid&type=product&tracking_id=d60c0833-5510-41b0-8fb7-adc3805169c5&sid=search'],
#   ['Boneco Roronoa Zoro Action Figure Anime One Piece + Brinde',
#    '(207)',
#    '4.7',
#    '78',
#    'https://produto.mercadolivre.com.br/MLB-4188785062-boneco-roronoa-zoro-action-figure-anime-one-piece-brinde-_JM#polycard_client=search-nordic&position=31&search_layout=grid&type=item&tracking_id=d60c0833-5510-41b0-8fb7-adc3805169c5'],
#   ['Boneco Master Chief Halo Infinite Mark Vi Action Figure',
#    '(37)',
#    '4.2',
#    '190',
#    'https://www.mercadolivre.com.br/boneco-master-chief-halo-infinite-mark-vi-action-figure/p/MLB28768484#polycard_client=search-nordic&searchVariation=MLB28768484&wid=MLB4799161964&position=20&search_layout=grid&type=product&tracking_id=d60c0833-5510-41b0-8fb7-adc3805169c5&sid=search'],
#   ['Boneco Articulado Lucky Robô 3d Action Figure Dummy Enfeite',
#    '(134)',
#    '4.2',
#    '44',
#    'https://produto.mercadolivre.com.br/MLB-4898385576-boneco-articulado-lucky-rob-3d-action-figure-dummy-enfeite-_JM?searchVariation=181080979644#polycard_client=search-nordic&searchVariation=181080979644&position=32&search_layout=grid&type=item&tracking_id=d60c0833-5510-41b0-8fb7-adc3805169c5'],
#   ['Pop! Funko Mewtwo #581 | Pokémon',
#    '(28)',
#    '4.8',
#    '139',
#    'https://www.mercadolivre.com.br/pop-funko-mewtwo-581-pokemon/p/MLB19763235#polycard_client=search-nordic&searchVariation=MLB19763235&wid=MLB3547245995&position=26&search_layout=grid&type=product&tracking_id=d60c0833-5510-41b0-8fb7-adc3805169c5&sid=search'],
#   ['Action Figure Homem Aranha Miles Morales 13cm Personalizável',
#    '(13)',
#    '4.4',
#    '141',
#    'https://www.mercadolivre.com.br/action-figure-homem-aranha-miles-morales-13cm-personalizavel/p/MLB39675434#polycard_client=search-nordic&searchVariation=MLB39675434&wid=MLB3921791885&position=6&search_layout=grid&type=product&tracking_id=d60c0833-5510-41b0-8fb7-adc3805169c5&sid=search'],
#   ["Action Figure Frieren Beyond Journey's Luminasta Sega",
#    '(11)',
#    '4.6',
#    '189',
#    'https://www.mercadolivre.com.br/action-figure-frieren-beyond-journeys-luminasta-sega/p/MLB37217686#polycard_client=search-nordic&searchVariation=MLB37217686&wid=MLB3796825515&position=9&search_layout=grid&type=product&tracking_id=d60c0833-5510-41b0-8fb7-adc3805169c5&sid=search'],
#   ['Boneco One Piece Luffy Action Figure Pvc Black Friday',
#    '(215)',
#    '4.7',
#    '51',
#    'https://produto.mercadolivre.com.br/MLB-3469027985-boneco-one-piece-luffy-action-figure-pvc-black-friday-_JM#polycard_client=search-nordic&position=33&search_layout=grid&type=item&tracking_id=d60c0833-5510-41b0-8fb7-adc3805169c5'],
#   ['Boneco Deadpool Amazing 2.0 Articulado Action Figure',
#    '(44)',
#    '4.0',
#    '202',
#    'https://www.mercadolivre.com.br/boneco-deadpool-amazing-20-articulado-action-figure/p/MLB36243301#polycard_client=search-nordic&searchVariation=MLB36243301&wid=MLB3949178377&position=11&search_layout=grid&type=product&tracking_id=d60c0833-5510-41b0-8fb7-adc3805169c5&sid=search'],
#   ['Action Figure Bumblebee Fusca Boneco Transformers Vira Robo',
#    '(13)',
#    '4.5',
#    '211',
#    'https://www.mercadolivre.com.br/action-figure-bumblebee-fusca-boneco-transformers-vira-robo/p/MLB41201767#polycard_client=search-nordic&searchVariation=MLB41201767&wid=MLB5177169472&position=7&search_layout=grid&type=product&tracking_id=d60c0833-5510-41b0-8fb7-adc3805169c5&sid=search'],
#   ['Kit Com 12 Bonecos Miniatura Patrulha Canina Action Figure',
#    '(18)',
#    '4.3',
#    '78',
#    'https://produto.mercadolivre.com.br/MLB-3725670961-kit-com-12-bonecos-miniatura-patrulha-canina-action-figure-_JM#polycard_client=search-nordic&position=34&search_layout=grid&type=item&tracking_id=d60c0833-5510-41b0-8fb7-adc3805169c5'],
#   ['Boneco Action Figure Sanemi Shinazugawa Demon Slayer',
#    '(7)',
#    '4.9',
#    '75',
#    'https://produto.mercadolivre.com.br/MLB-4751329292-boneco-action-figure-sanemi-shinazugawa-demon-slayer-_JM#polycard_client=search-nordic&position=35&search_layout=grid&type=item&tracking_id=d60c0833-5510-41b0-8fb7-adc3805169c5'],
#   ['Boneco Action Figure Dragon Ball Z 22cm',
#    '(77)',
#    '4.8',
#    '97',
#    'https://produto.mercadolivre.com.br/MLB-4438022142-boneco-action-figure-dragon-ball-z-22cm-_JM#polycard_client=search-nordic&position=36&search_layout=grid&type=item&tracking_id=d60c0833-5510-41b0-8fb7-adc3805169c5'],
#   ['Optimus Prime Transformers Robo Brinquedo Action Figure',
#    '(90)',
#    '4.3',
#    '148',
#    'https://www.mercadolivre.com.br/optimus-prime-transformers-robo-brinquedo-action-figure/p/MLB26614281#polycard_client=search-nordic&searchVariation=MLB26614281&wid=MLB4592711512&position=12&search_layout=grid&type=product&tracking_id=d60c0833-5510-41b0-8fb7-adc3805169c5&sid=search'],
#   ['Transformers Bumblebee Robo Brinquedo Action Figure',
#    '(27)',
#    '3.9',
#    '146',
#    'https://www.mercadolivre.com.br/transformers-bumblebee-robo-brinquedo-action-figure/p/MLB29781816#polycard_client=search-nordic&searchVariation=MLB29781816&wid=MLB3662983751&position=14&search_layout=grid&type=product&tracking_id=d60c0833-5510-41b0-8fb7-adc3805169c5&sid=search'],
#   ['Kit 6 Bonecos Pokémon Pikachu Squirtle Bulbasaur Charmander',
#    '(8)',
#    '3.6',
#    '66',
#    'https://produto.mercadolivre.com.br/MLB-3691844789-kit-6-bonecos-pokemon-pikachu-squirtle-bulbasaur-charmander-_JM#polycard_client=search-nordic&position=37&search_layout=grid&type=item&tracking_id=d60c0833-5510-41b0-8fb7-adc3805169c5'],
#   ['Boneco Wolverine Amazing Articulado Action Figure',
#    'nd',
#    'nd',
#    '240',
#    'https://produto.mercadolivre.com.br/MLB-5229526094-boneco-wolverine-amazing-articulado-action-figure-_JM#polycard_client=search-nordic&position=38&search_layout=grid&type=item&tracking_id=d60c0833-5510-41b0-8fb7-adc3805169c5'],
#   ['Boneco Action Figure One Piece Monkey D. Luffy - 28cm',
#    '(9)',
#    '4.9',
#    '122',
#    'https://produto.mercadolivre.com.br/MLB-5079354918-boneco-action-figure-one-piece-monkey-d-luffy-28cm-_JM#polycard_client=search-nordic&position=39&search_layout=grid&type=item&tracking_id=d60c0833-5510-41b0-8fb7-adc3805169c5'],
#   ['Kit One Piece Luffy E Zoro Bonecos Pvc Action Figure Coleção',
#    '(141)',
#    '4.6',
#    '78',
#    'https://produto.mercadolivre.com.br/MLB-4580439298-kit-one-piece-luffy-e-zoro-bonecos-pvc-action-figure-coleco-_JM#polycard_client=search-nordic&position=40&search_layout=grid&type=item&tracking_id=d60c0833-5510-41b0-8fb7-adc3805169c5'],
#   ['Banguela Anda Com Luz E Som Como Treinar O Seu Dragão',
#    '(97)',
#    '4.4',
#    '97',
#    'https://www.mercadolivre.com.br/banguela-anda-com-luz-e-som-como-treinar-o-seu-drago/p/MLB20957246#polycard_client=search-nordic&searchVariation=MLB20957246&wid=MLB3258678035&position=10&search_layout=grid&type=product&tracking_id=d60c0833-5510-41b0-8fb7-adc3805169c5&sid=search'],
#   ['Boneco Toad Turma Do Mario Articulável Action Figure Vinil',
#    '(71)',
#    '4.9',
#    '59',
#    'https://produto.mercadolivre.com.br/MLB-2102776066-boneco-toad-turma-do-mario-articulavel-action-figure-vinil-_JM#polycard_client=search-nordic&position=41&search_layout=grid&type=item&tracking_id=d60c0833-5510-41b0-8fb7-adc3805169c5'],
#   ['Boneca Tiffany A Noiva De Chucky Geek Coleção',
#    '(24)',
#    '4.9',
#    '415',
#    'https://www.mercadolivre.com.br/boneca-tiffany-a-noiva-de-chucky-geek-coleco/p/MLB25007645#polycard_client=search-nordic&searchVariation=MLB25007645&wid=MLB3670849013&position=13&search_layout=grid&type=product&tracking_id=d60c0833-5510-41b0-8fb7-adc3805169c5&sid=search'],
#   ['Action Figure Transformers Camaro Bumblebee C/acessórios',
#    '(20)',
#    '3.6',
#    '162',
#    'https://www.mercadolivre.com.br/action-figure-transformers-camaro-bumblebee-cacessorios/p/MLB30180871#polycard_client=search-nordic&searchVariation=MLB30180871&wid=MLB4703226628&position=18&search_layout=grid&type=product&tracking_id=d60c0833-5510-41b0-8fb7-adc3805169c5&sid=search'],
#   ['Boneco Action Figure One Piece Monkey D Luffy 28 Cm',
#    '(84)',
#    '4.8',
#    '110',
#    'https://produto.mercadolivre.com.br/MLB-3497486793-boneco-action-figure-one-piece-monkey-d-luffy-28-cm-_JM#polycard_client=search-nordic&position=42&search_layout=grid&type=item&tracking_id=d60c0833-5510-41b0-8fb7-adc3805169c5'],
#   ['Boneco Roronoa Zoro Action Figure Anime One Piece',
#    '(2)',
#    '5.0',
#    '78',
#    'https://produto.mercadolivre.com.br/MLB-3619344067-boneco-roronoa-zoro-action-figure-anime-one-piece-_JM#polycard_client=search-nordic&position=43&search_layout=grid&type=item&tracking_id=d60c0833-5510-41b0-8fb7-adc3805169c5'],
#   ['6 Bonecos Pokemon Pikachu Venusaur Action Figures Coleção',
#    '(5)',
#    '3.8',
#    '138',
#    'https://produto.mercadolivre.com.br/MLB-4286441650-6-bonecos-pokemon-pikachu-venusaur-action-figures-coleco-_JM#polycard_client=search-nordic&position=44&search_layout=grid&type=item&tracking_id=d60c0833-5510-41b0-8fb7-adc3805169c5'],
#   ['Boneco Donkey Kong Action Figure 15cm Decoração Colecionável',
#    '(1)',
#    '5.0',
#    '78',
#    'https://produto.mercadolivre.com.br/MLB-4795362274-boneco-donkey-kong-action-figure-15cm-decoraco-colecionavel-_JM#polycard_client=search-nordic&position=45&search_layout=grid&type=item&tracking_id=d60c0833-5510-41b0-8fb7-adc3805169c5'],
#   ['Boneco Articulado Dummy Warcraft Robô Action Figure Lucky 13',
#    '(67)',
#    '3.9',
#    '78',
#    'https://produto.mercadolivre.com.br/MLB-4973094364-boneco-articulado-dummy-warcraft-rob-action-figure-lucky-13-_JM?searchVariation=181281161190#polycard_client=search-nordic&searchVariation=181281161190&position=46&search_layout=grid&type=item&tracking_id=d60c0833-5510-41b0-8fb7-adc3805169c5'],
#   ['Figura De Acción Dc Toys Knuckles De Dc Toys',
#    '(1)',
#    '5.0',
#    '120',
#    'https://www.mercadolivre.com.br/figura-de-accion-dc-toys-knuckles-de-dc-toys/p/MLB36077732#polycard_client=search-nordic&searchVariation=MLB36077732&wid=MLB5050159804&position=24&search_layout=grid&type=product&tracking_id=d60c0833-5510-41b0-8fb7-adc3805169c5&sid=search'],
#   ['05 Bonecos Sonic Metal Hedgehog Talis Knuckles Sonic Metal',
#    '(51)',
#    '4.6',
#    '139',
#    'https://produto.mercadolivre.com.br/MLB-2874850080-05-bonecos-sonic-metal-hedgehog-talis-knuckles-sonic-metal-_JM#polycard_client=search-nordic&position=47&search_layout=grid&type=item&tracking_id=d60c0833-5510-41b0-8fb7-adc3805169c5'],
#   ['Boneco Articulado Minato Namikaze Naruto Bandai Original',
#    '(23)',
#    '4.9',
#    '179',
#    'https://www.mercadolivre.com.br/boneco-articulado-minato-namikaze-naruto-bandai-original/p/MLB19729213#polycard_client=search-nordic&searchVariation=MLB19729213&wid=MLB3859051705&position=19&search_layout=grid&type=product&tracking_id=d60c0833-5510-41b0-8fb7-adc3805169c5&sid=search'],
#   ['Coleção Action Figure Sonic -com 6 Bonecos *pronta Entrega*',
#    '(177)',
#    '4.1',
#    '78',
#    'https://produto.mercadolivre.com.br/MLB-709706315-coleco-action-figure-sonic-com-6-bonecos-pronta-entrega-_JM?searchVariation=174550727254#polycard_client=search-nordic&searchVariation=174550727254&position=48&search_layout=grid&type=item&tracking_id=d60c0833-5510-41b0-8fb7-adc3805169c5'],
#   ['Action Figure One Piece Monkey D. Luffy Gear 5 Boneco',
#    'nd',
#    'nd',
#    '159',
#    'https://produto.mercadolivre.com.br/MLB-3907138569-action-figure-one-piece-monkey-d-luffy-gear-5-boneco-_JM#polycard_client=search-nordic&position=49&search_layout=grid&type=item&tracking_id=d60c0833-5510-41b0-8fb7-adc3805169c5'],
#   ['Action Figure Boneco Kakashi Sensei Naruto Colecionavel',
#    '(7)',
#    '5.0',
#    '69',
#    'https://produto.mercadolivre.com.br/MLB-4522531534-action-figure-boneco-kakashi-sensei-naruto-colecionavel-_JM#polycard_client=search-nordic&position=50&search_layout=grid&type=item&tracking_id=d60c0833-5510-41b0-8fb7-adc3805169c5']]}
